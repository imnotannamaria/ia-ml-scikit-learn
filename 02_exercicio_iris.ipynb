# %% [markdown]
# # Exercício 01

# %% [markdown]
# Criar um loop para rodar o modelo knn com valores de K, de 1 até 25. Depois fazer o teste de performance para cada um dos valores de K e apresentar os resultados.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris = load_iris()

x = iris.data
y = iris.target

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)

# %% [markdown]
# ### Com dicionário

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

performance_values = {}
k = 1

while k <= 25:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train, y_train)
    predict = knn.predict(x_test)
    hits = metrics.accuracy_score(y_test, predict)
    performance_values[k] = round(hits, 4)
    k += 1

print(performance_values)
# Out:
# {1: 0.9737, 2: 0.9737, 3: 0.9737, 4: 1.0, 5: 1.0, 6: 0.9737, 7: 0.9737, 8: 0.9737, 9: 0.9737, 10: 0.9737, 11: 1.0, 12: 1.0, 13: 1.0, 14: 0.9737, 15: 1.0, 16: 1.0, 17: 1.0, 18: 0.9737, 19: 1.0, 20: 0.9737, 21: 0.9474, 22: 0.9737, 23: 0.9737, 24: 0.9474, 25: 0.9474}

# %% [markdown]
# ### Utilizando matplotlib para vizualização de dados com gráfico

# %%
import matplotlib.pyplot as plt

plt.plot(list(performance_values.keys()), list(performance_values.values()))
plt.xlabel("Valores de K")
plt.ylabel("Performance")
plt.show()
